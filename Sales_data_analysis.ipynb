# %% [markdown]
# <a href="https://colab.research.google.com/github/pankarpratiksha50/Data-Analysis-and-Data-science-Python-Projects/blob/main/Sales_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sale data analysis with python**
#
# (A part of big data analysis)

# %% [markdown]
# Restaurant sales dataset
#
# we have the sale of data of restaurant company from diffrent cities. This data is available in the excel file format. We are going to analyse and visualize the data.

# %% [markdown]
# importing the required lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing the dataset

# %%
data=pd.read_excel('/content/Sales-Data-Analysis (1).xlsx')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 250         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 251         NaN      10710  2022-12-29 00:00:00             Burgers
# 252         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 253         NaN      10712  2022-12-29 00:00:00               Fries
# 254         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %% [markdown]
# drop unwanted coloum

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data.head()
# Out:
#   Unnamed: 1           Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0   Order ID                 Date        Product      Price    Quantity
# 1      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 2      10453  2022-11-07 00:00:00      Beverages       2.95  745.762712
# 3      10454  2022-11-07 00:00:00  Sides & Other       4.99  200.400802
# 4      10455  2022-11-08 00:00:00        Burgers      12.99  569.668976
#
#       Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method             Manager       City
# 1        Online        Gift Card    Tom      Jackson     London
# 2        Online        Gift Card         Pablo Perez     Madrid
# 3      In-store        Gift Card       Joao    Silva     Lisbon
# 4      In-store      Credit Card       Walter Muller     Berlin

# %%
data.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data.columns=data.loc[0]

# %%
data.head(2)
# Out:
# 0 Order ID                 Date    Product Price    Quantity Purchase Type  \
# 1    10452  2022-11-07 00:00:00      Fries  3.49  573.065903       Online
# 2    10453  2022-11-07 00:00:00  Beverages  2.95  745.762712       Online
#
# 0 Payment Method             Manager    City
# 1      Gift Card    Tom      Jackson  London
# 2      Gift Card         Pablo Perez  Madrid

# %% [markdown]
# drop the unwanted list now

# %%
data.drop(0,inplace=True)

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 250    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 251    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 252    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 253    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 254    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method             Manager    City
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %% [markdown]
# consider the manager columns

# %%
data.head()
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card    Tom      Jackson  London
# 2       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store       Gift Card       Joao    Silva  Lisbon
# 4     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Walter Muller  Berlin

# %%
data.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data['Manager']=data['Manager'].str.strip().str.replace(r'\s+', ' ',regex=True)

# %%
data.head(20)
# Out:
# 0  Order ID                 Date             Product  Price    Quantity  \
# 1     10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5     10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6     10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7     10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 8     10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 9     10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 10    10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 11    10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# 12    10464  2022-11-09 00:00:00       Sides & Other   4.99  200.400802
# ...

# %%
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.describe()
# Out:
# /tmp/ipython-input-22-3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 250    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 251    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 252    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 253    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 254    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method        Manager    City
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.describe()
# Out:
# /tmp/ipython-input-27-3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# ...

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data[data['Order ID']==10483]
# Out:
# 0  Order ID                 Date    Product Price    Quantity Purchase Type  \
# 61    10483  2022-11-13 00:00:00  Beverages  2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 61    Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID']==10484]
# Out:
# 0  Order ID                 Date        Product Price    Quantity  \
# 62    10484  2022-11-13 00:00:00  Sides & Other  4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 62     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID']==10485]
# Out:
# 0  Order ID                 Date  Product  Price  Quantity Purchase Type  \
# 63    10485  2022-11-14 00:00:00  Burgers  12.99  523.4796     In-store
#
# 0  Payment Method     Manager    City
# 63    Credit Card  Joao Silva  Lisbon

# %%
data.drop(32,inplace=True)

# %%
data[data['Order ID']==10483]
# Out:
# 0  Order ID                 Date    Product Price    Quantity Purchase Type  \
# 61    10483  2022-11-13 00:00:00  Beverages  2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 61    Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID']==10484]
# Out:
# 0  Order ID                 Date        Product Price    Quantity  \
# 62    10484  2022-11-13 00:00:00  Sides & Other  4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 62     In-store     Credit Card  Joao Silva  Lisbon

# %% [markdown]
# converting datatype of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    object
#  1   Date            253 non-null    object
#  2   Product         253 non-null    object
#  3   Price           253 non-null    object
#  4   Quantity        253 non-null    object
#  5   Purchase Type   253 non-null    object
#  6   Payment Method  253 non-null    object
#  7   Manager         253 non-null    object
#  8   City            253 non-null    object
# dtypes: object(9)
# memory usage: 19.8+ KB

# %%
data.Quantity=data.Quantity.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    object
#  1   Date            253 non-null    object
#  2   Product         253 non-null    object
#  3   Price           253 non-null    object
#  4   Quantity        253 non-null    float64
#  5   Purchase Type   253 non-null    object
#  6   Payment Method  253 non-null    object
#  7   Manager         253 non-null    object
#  8   City            253 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 19.8+ KB

# %%
data.Quantity=data.Quantity.round()

# %%
data.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 250    200.0
# 251    754.0
# 252    281.0
# 253    630.0
# 254    678.0
# Name: Quantity, Length: 253, dtype: float64

# %%
data.Quantity=data.Quantity.astype(int)

# %%
data['Quantity']
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    678
# Name: Quantity, Length: 253, dtype: int64

# %%
data.Date=pd.to_datetime(data.Date)

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    object
#  1   Date            253 non-null    datetime64[ns]
#  2   Product         253 non-null    object
#  3   Price           253 non-null    object
#  4   Quantity        253 non-null    int64
#  5   Purchase Type   253 non-null    object
#  6   Payment Method  253 non-null    object
#  7   Manager         253 non-null    object
#  8   City            253 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 19.8+ KB

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49       573       Online
# 2      10453 2022-11-07           Beverages   2.95       746       Online
# 3      10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4      10455 2022-11-08             Burgers  12.99       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253    10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# ...

# %% [markdown]
# Analyzing the data

# %% [markdown]
# **Q.1)The most payment method?**

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].nunique()
# Out:
# 3

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    119
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize=True) *100
# Out:
# Payment Method
# Credit Card    47.035573
# Cash           30.039526
# Gift Card      22.924901
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %% [markdown]
# **Q.2)Most selling product**
#
# by quntity
#
# by revenue

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Beverages             34310
# Burgers               29018
# Chicken Sandwiches    11133
# Fries                 32023
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34310
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
most_quality=data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quality
# Out:
# Product
# Beverages             34310
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
type(most_quality)
# Out:
# pandas.core.series.Series

# %%
most_quality=most_quality.reset_index()

# %%
most_quality
# Out:
#               Product  Quantity
# 0           Beverages     34310
# 1               Fries     32023
# 2             Burgers     29018
# 3  Chicken Sandwiches     11133
# 4       Sides & Other      9800

# %%
type(most_quality)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(9,4))
plt.bar(most_quality['Product'],most_quality['Quantity'],color=['red','yellow','blue','green','black'],width=0.6)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# **by revenue**

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Revenue']=data['Quantity'] * data['Price']

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49       573       Online
# 2      10453 2022-11-07           Beverages   2.95       746       Online
# 3      10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4      10455 2022-11-08             Burgers  12.99       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253    10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# ...

# %%
most_revenue=data.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages              101214.5
# Sides & Other           48902.0
# Name: Revenue, dtype: object

# %%
most_revenue=most_revenue.reset_index()

# %%
most_revenue
# Out:
#               Product    Revenue
# 0             Burgers  376943.82
# 1               Fries  125626.57
# 2  Chicken Sandwiches  114612.45
# 3           Beverages   101214.5
# 4       Sides & Other    48902.0

# %%
plt.figure(figsize=(9,4))
plt.bar(most_revenue['Product'],most_revenue['Revenue'],color=['red','yellow','blue','green','black'],width=0.6)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# **which manager earnd maximum revenue?**

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49       573       Online
# 2      10453 2022-11-07           Beverages   2.95       746       Online
# 3      10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4      10455 2022-11-08             Burgers  12.99       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253    10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# ...

# %%
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.City.nunique()
# Out:
# 5

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    239635.39
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: object

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       239635.39
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: object

# %% [markdown]
# **datawise revenue**

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid   2200.7
# 3      Gift Card     Joao Silva  Lisbon    998.0
# 4    Credit Card  Walter Muller  Berlin   7404.3
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    object
#  1   Date            253 non-null    datetime64[ns]
#  2   Product         253 non-null    object
#  3   Price           253 non-null    object
#  4   Quantity        253 non-null    int64
#  5   Purchase Type   253 non-null    object
#  6   Payment Method  253 non-null    object
#  7   Manager         253 non-null    object
#  8   City            253 non-null    object
#  9   Revenue         253 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 29.8+ KB

# %%
data.plot('Date', 'Revenue',color='red',linewidth=2)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Average revenue**

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid   2200.7
# 3      Gift Card     Joao Silva  Lisbon    998.0
# 4    Credit Card  Walter Muller  Berlin   7404.3
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Revenue'].mean()
# Out:
# np.float64(3032.803715415014)

# %% [markdown]
# **Average revenue of november and december months**

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1    10452 2022-11-07               Fries   3.49       573       Online
# 2    10453 2022-11-07           Beverages   2.95       746       Online
# 3    10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4    10455 2022-11-08             Burgers  12.99       570     In-store
# 5    10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid   2200.7
# 3      Gift Card     Joao Silva  Lisbon    998.0
# 4    Credit Card  Walter Muller  Berlin   7404.3
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Month']=data['Date'].dt.month

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49       573       Online
# 2      10453 2022-11-07           Beverages   2.95       746       Online
# 3      10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4      10455 2022-11-08             Burgers  12.99       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253    10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
maa=data[data['Month']==11]
maa
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49       573       Online
# 2      10453 2022-11-07           Beverages   2.95       746       Online
# 3      10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4      10455 2022-11-08             Burgers  12.99       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 109    10568 2022-11-30           Beverages   2.95       678       Online
# 110    10569 2022-11-30       Sides & Other   4.99       200       Online
# 128    10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129    10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130    10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
maa.Revenue.mean()
# Out:
# np.float64(2946.5626785714308)

# %%
mbb=data[data['Month']==12]
mbb
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111    10570 2022-12-01             Burgers  12.99       493       Online
# 112    10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113    10572 2022-12-01               Fries   3.49       573       Online
# 114    10573 2022-12-01           Beverages   2.95       678       Online
# 115    10574 2022-12-01       Sides & Other   4.99       200       Online
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253    10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %% [markdown]
# **standard deviation of revenu and quantity**

# %%
data['Quantity'].std()
# Out:
# 214.96756467336485

# %%
data['Quantity'].std()
# Out:
# np.float64(2423.8598403575334)

# %% [markdown]
# **varience of revenue and quality**

# %%
data['Quantity'].var()
# Out:
# 46211.0538615973

# %%
data['Revenue'].var()
# Out:
# np.float64(5875096.525698046)
